# %% [markdown]
# # Notebook 07: Ship Mode Performance Analysis
#
# ## Objective
# This notebook evaluates shipping performance across different ship modes.
#
# ### Key Tasks:
# - Compare average lead time by ship mode
# - Analyze shipment volume by ship mode
# - Calculate delay frequency
# - Identify best and worst performing ship modes
# - Evaluate descriptive cost-time tradeoffs
#
# This step helps understand how shipping choices impact efficiency and delays.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
# Load dataset
ncd = pd.read_csv("/content/featured_nassau_data.csv")

# Ensure datetime
ncd["Order Date"] = pd.to_datetime(ncd["Order Date"])
ncd["Ship Date"] = pd.to_datetime(ncd["Ship Date"])

ncd.head()
# Out:
#    Row ID                      Order ID Order Date  Ship Date       Ship Mode  \
# 0       1  US-2021-103800-CHO-MIL-31000 2024-01-03 2024-01-09  Standard Class
# 1       2  US-2021-112326-CHO-TRI-54000 2024-01-04 2024-01-11  Standard Class
# 2       3  US-2021-112326-CHO-NUT-13000 2024-01-04 2024-01-09  Standard Class
# 3       4  US-2021-112326-CHO-SCR-58000 2024-01-04 2024-01-11  Standard Class
# 4       5  US-2021-141817-CHO-TRI-54000 2024-01-05 2024-01-12  Standard Class
#
#    Customer ID Country/Region          City State/Province Postal Code  \
# 0       103800  United States       Houston          Texas       77095
# 1       112326  United States    Naperville       Illinois       60540
# 2       112326  United States    Naperville       Illinois       60540
# 3       112326  United States    Naperville       Illinois       60540
# 4       141817  United States  Philadelphia   Pennsylvania       19143
#
# ...

# %% [markdown]
# ## Ship Mode Performance Summary

# %%
ship_mode_summary = ncd.groupby("Ship Mode").agg(
    Total_Shipments=("Order ID", "count"),
    Avg_Lead_Time=("Shipping Lead Time", "mean"),
    Lead_Time_Std=("Shipping Lead Time", "std")
).reset_index()

ship_mode_summary["Avg_Lead_Time"] = ship_mode_summary["Avg_Lead_Time"].round(2)
ship_mode_summary["Lead_Time_Std"] = ship_mode_summary["Lead_Time_Std"].round(2)

ship_mode_summary
# Out:
#         Ship Mode  Total_Shipments  Avg_Lead_Time  Lead_Time_Std
# 0     First Class             1011           1.98           0.83
# 1        Same Day              362           0.49           0.50
# 2    Second Class             1366           3.49           1.13
# 3  Standard Class             4331           5.00           1.42

# %% [markdown]
# ## Delay Frequency by Ship Mode

# %%
delay_analysis = ncd.groupby(["Ship Mode", "Delay Status"]).size().unstack()

delay_analysis
# Out:
# Delay Status    Delayed  On-Time
# Ship Mode
# First Class         NaN   1011.0
# Same Day            NaN    362.0
# Second Class        NaN   1366.0
# Standard Class   1741.0   2589.0

# %%
# Convert to percentage
delay_percent = delay_analysis.div(delay_analysis.sum(axis=1), axis=0) * 100
delay_percent.round(2)
# Out:
# Delay Status    Delayed  On-Time
# Ship Mode
# First Class         NaN   100.00
# Same Day            NaN   100.00
# Second Class        NaN   100.00
# Standard Class    40.21    59.79

# %% [markdown]
# ## Combine Metrics

# %%
# Merge summary + delay
delay_percent.reset_index(inplace=True)

ship_mode_final = ship_mode_summary.merge(delay_percent, on="Ship Mode")

ship_mode_final
# Out:
#         Ship Mode  Total_Shipments  Avg_Lead_Time  Lead_Time_Std    Delayed  \
# 0     First Class             1011           1.98           0.83        NaN
# 1        Same Day              362           0.49           0.50        NaN
# 2    Second Class             1366           3.49           1.13        NaN
# 3  Standard Class             4331           5.00           1.42  40.207852
#
#       On-Time
# 0  100.000000
# 1  100.000000
# 2  100.000000
# 3   59.792148

# %% [markdown]
# ## Rank Ship Modes

# %%
# Rank by efficiency (lower lead time = better)
ship_mode_final["Efficiency_Rank"] = ship_mode_final["Avg_Lead_Time"].rank()

ship_mode_final.sort_values("Efficiency_Rank")
# Out:
#         Ship Mode  Total_Shipments  Avg_Lead_Time  Lead_Time_Std    Delayed  \
# 1        Same Day              362           0.49           0.50        NaN
# 0     First Class             1011           1.98           0.83        NaN
# 2    Second Class             1366           3.49           1.13        NaN
# 3  Standard Class             4331           5.00           1.42  40.207852
#
#       On-Time  Efficiency_Rank
# 1  100.000000              1.0
# 0  100.000000              2.0
# 2  100.000000              3.0
# 3   59.792148              4.0

# %% [markdown]
# ## Business Interpretation
#
# - Ship modes with lower average lead time are more efficient
# - Ship modes with higher delay percentage indicate reliability issues
# - High volume + high delay = operational risk
# - Trade-off exists between speed and cost
#
# This analysis helps determine which shipping strategy should be prioritized.

# %% [markdown]
# ## Final Check

# %%
ship_mode_final
# Out:
#         Ship Mode  Total_Shipments  Avg_Lead_Time  Lead_Time_Std    Delayed  \
# 0     First Class             1011           1.98           0.83        NaN
# 1        Same Day              362           0.49           0.50        NaN
# 2    Second Class             1366           3.49           1.13        NaN
# 3  Standard Class             4331           5.00           1.42  40.207852
#
#       On-Time  Efficiency_Rank
# 0  100.000000              2.0
# 1  100.000000              1.0
# 2  100.000000              3.0
# 3   59.792148              4.0

# %% [markdown]
# ## Save Output

# %%
ship_mode_final.to_csv("/content/ship_mode_detailed_analysis.csv", index=False)

print("Ship mode analysis saved successfully.")
# Out:
# Ship mode analysis saved successfully.
