# %% [markdown]
# # Notebook 04: Route Definition & Aggregation
#
# ## Objective
# This notebook focuses on defining and aggregating logistics routes to measure shipping performance at the route level.
#
# ### Key Tasks:
# - Define routes using Factory → State and Factory → Region
# - Calculate total shipments (Route Volume)
# - Calculate average shipping lead time
# - Measure lead time variability
# - Prepare route-level datasets for benchmarking
#
# This step transforms order-level data into actionable route-level insights.

# %%
import pandas as pd
import numpy as np
import statistics as stats

pd.set_option("display.max_columns", None)

# %%
# Load feature-engineered dataset
file_path = r"/content/featured_nassau_data.csv"
ncd = pd.read_csv(file_path)

ncd.head()
# Out:
#    Row ID                      Order ID  Order Date   Ship Date  \
# 0       1  US-2021-103800-CHO-MIL-31000  2024-01-03  2024-01-09
# 1       2  US-2021-112326-CHO-TRI-54000  2024-01-04  2024-01-11
# 2       3  US-2021-112326-CHO-NUT-13000  2024-01-04  2024-01-09
# 3       4  US-2021-112326-CHO-SCR-58000  2024-01-04  2024-01-11
# 4       5  US-2021-141817-CHO-TRI-54000  2024-01-05  2024-01-12
#
#         Ship Mode  Customer ID Country/Region          City State/Province  \
# 0  Standard Class       103800  United States       Houston          Texas
# 1  Standard Class       112326  United States    Naperville       Illinois
# 2  Standard Class       112326  United States    Naperville       Illinois
# 3  Standard Class       112326  United States    Naperville       Illinois
# 4  Standard Class       141817  United States  Philadelphia   Pennsylvania
#
#   Postal Code   Division    Region     Product ID  \
# 0       77095  Chocolate  Interior  CHO-MIL-31000
# ...

# %%
# Ensure datetime format
ncd["Order Date"] = pd.to_datetime(ncd["Order Date"])
ncd["Ship Date"] = pd.to_datetime(ncd["Ship Date"])

# %% [markdown]
# ## Route Aggregation (Factory → State)
#
# Each route is defined as:
# Factory → Customer State
#
# We calculate:
# - Total shipments (Route Volume)
# - Average Lead Time
# - Lead Time Variability

# %%
# Aggregate at Route_State level
route_state_summary = ncd.groupby("Route_State").agg(
    Total_Shipments=("Order ID", "count"),
    Avg_Lead_Time=("Shipping Lead Time", "mean"),
    Lead_Time_Std=("Shipping Lead Time", "std"),
    Min_Lead_Time=("Shipping Lead Time", "min"),
    Max_Lead_Time=("Shipping Lead Time", "max")
).reset_index()

# %%
# Round values for readability
route_state_summary["Avg_Lead_Time"] = route_state_summary["Avg_Lead_Time"].round(2)
route_state_summary["Lead_Time_Std"] = route_state_summary["Lead_Time_Std"].round(2)

route_state_summary.head()
# Out:
#                         Route_State  Total_Shipments  Avg_Lead_Time  \
# 0           Lot's O' Nuts → Alabama               34           4.59
# 1           Lot's O' Nuts → Alberta               16           3.50
# 2           Lot's O' Nuts → Arizona              111           3.86
# 3          Lot's O' Nuts → Arkansas               31           4.19
# 4  Lot's O' Nuts → British Columbia               18           5.00
#
#    Lead_Time_Std  Min_Lead_Time  Max_Lead_Time
# 0           1.84              1              7
# 1           1.32              2              7
# 2           2.03              0              7
# 3           1.54              0              7
# 4           1.53              2              7

# %% [markdown]
# ## Route Aggregation (Factory → Region)
#
# Each route is defined as:
# Factory → Customer Region

# %%
# Aggregate at Route_Region level
route_region_summary = ncd.groupby("Route_Region").agg(
    Total_Shipments=("Order ID", "count"),
    Avg_Lead_Time=("Shipping Lead Time", "mean"),
    Lead_Time_Std=("Shipping Lead Time", "std"),
    Min_Lead_Time=("Shipping Lead Time", "min"),
    Max_Lead_Time=("Shipping Lead Time", "max")
).reset_index()

# %%
# Round values
route_region_summary["Avg_Lead_Time"] = route_region_summary["Avg_Lead_Time"].round(2)
route_region_summary["Lead_Time_Std"] = route_region_summary["Lead_Time_Std"].round(2)

route_region_summary.head()
# Out:
#                 Route_Region  Total_Shipments  Avg_Lead_Time  Lead_Time_Std  \
# 0   Lot's O' Nuts → Atlantic             1661           3.93           1.87
# 1       Lot's O' Nuts → Gulf              897           4.10           1.83
# 2   Lot's O' Nuts → Interior             1321           4.09           1.82
# 3    Lot's O' Nuts → Pacific             1813           3.92           1.87
# 4  Secret Factory → Atlantic               72           4.04           1.81
#
#    Min_Lead_Time  Max_Lead_Time
# 0              0              7
# 1              0              7
# 2              0              7
# 3              0              7
# 4              1              7

# %%
# Top routes by volume
route_state_summary.sort_values(by="Total_Shipments", ascending=False).head(10)
# Out:
#                       Route_State  Total_Shipments  Avg_Lead_Time  \
# 5      Lot's O' Nuts → California             1125           3.85
# 144  Wicked Choccy's → California              823           4.09
# 34       Lot's O' Nuts → New York              645           4.00
# 49          Lot's O' Nuts → Texas              569           4.14
# 173    Wicked Choccy's → New York              436           3.96
# 189       Wicked Choccy's → Texas              388           3.96
# 42   Lot's O' Nuts → Pennsylvania              331           4.17
# 53     Lot's O' Nuts → Washington              269           4.02
# 13       Lot's O' Nuts → Illinois              267           3.94
# 38           Lot's O' Nuts → Ohio              262           3.46
#
#      Lead_Time_Std  Min_Lead_Time  Max_Lead_Time
# 5             1.88              0              7
# 144           1.87              0              7
# 34            1.91              0              7
# ...

# %%
# Slowest routes
route_state_summary.sort_values(by="Avg_Lead_Time", ascending=False).head(10)
# Out:
#                                    Route_State  Total_Shipments  \
# 133           The Other Factory → Rhode Island                1
# 124               The Other Factory → Missouri                1
# 127             The Other Factory → New Jersey                3
# 71                   Secret Factory → Maryland                3
# 75                Secret Factory → Mississippi                1
# 99                      Sugar Shack → Delaware                1
# 107                 Sugar Shack → Rhode Island                1
# 78              Secret Factory → New Hampshire                1
# 138             The Other Factory → Washington                4
# 35   Lot's O' Nuts → Newfoundland And Labrador                6
#
#      Avg_Lead_Time  Lead_Time_Std  Min_Lead_Time  Max_Lead_Time
# 133           7.00            NaN              7              7
# 124           7.00            NaN              7              7
# 127           6.33           1.15              5              7
# ...

# %%
# Fastest routes
route_state_summary.sort_values(by="Avg_Lead_Time").head(10)
# Out:
#                             Route_State  Total_Shipments  Avg_Lead_Time  \
# 129  The Other Factory → North Carolina                1           0.00
# 120        The Other Factory → Kentucky                2           1.00
# 131          The Other Factory → Oregon                2           1.50
# 54        Lot's O' Nuts → West Virginia                2           1.50
# 112         The Other Factory → Arizona                2           2.00
# 125          The Other Factory → Nevada                1           2.00
# 126   The Other Factory → New Hampshire                2           2.00
# 108             Sugar Shack → Tennessee                1           2.00
# 80          Secret Factory → New Mexico                2           2.00
# 62            Secret Factory → Colorado                7           2.14
#
#      Lead_Time_Std  Min_Lead_Time  Max_Lead_Time
# 129            NaN              0              0
# 120           1.41              0              2
# ...

# %% [markdown]
# ## Interpretation of Metrics
#
# - Total Shipments → Route Volume
# - Avg Lead Time → Efficiency indicator
# - Lead Time Std → Consistency indicator
# - Min/Max Lead Time → Range of performance
#
# Routes with:
# - High Avg Lead Time → inefficient
# - High Std → inconsistent
# - High Volume + High Lead Time → bottleneck

# %%
route_state_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Route_State      196 non-null    object
#  1   Total_Shipments  196 non-null    int64
#  2   Avg_Lead_Time    196 non-null    float64
#  3   Lead_Time_Std    170 non-null    float64
#  4   Min_Lead_Time    196 non-null    int64
#  5   Max_Lead_Time    196 non-null    int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 9.3+ KB

# %%
route_region_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Route_Region     20 non-null     object
#  1   Total_Shipments  20 non-null     int64
#  2   Avg_Lead_Time    20 non-null     float64
#  3   Lead_Time_Std    20 non-null     float64
#  4   Min_Lead_Time    20 non-null     int64
#  5   Max_Lead_Time    20 non-null     int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.1+ KB

# %%
# Save datasets
route_state_summary.to_csv("/content/route_state_summary.csv", index=False)
route_region_summary.to_csv("/content/route_region_summary.csv", index=False)

print("Route aggregation datasets saved successfully.")
# Out:
# Route aggregation datasets saved successfully.
