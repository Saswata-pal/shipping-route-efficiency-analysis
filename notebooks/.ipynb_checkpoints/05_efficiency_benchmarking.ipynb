# %% [markdown]
# # Notebook 05: Efficiency Benchmarking
#
# ## Objective
# This notebook focuses on benchmarking route performance to identify the most efficient and least efficient logistics routes.
#
# ### Key Tasks:
# - Rank routes based on average lead time
# - Identify top 10 most efficient routes
# - Identify bottom 10 least efficient routes
# - Develop a Route Efficiency Score
# - Compare performance across ship modes
#
# This step enables data-driven decision-making for logistics optimization.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
# Load route-level dataset
route_state = pd.read_csv("/content/route_state_summary.csv")

route_state.head()
# Out:
#                         Route_State  Total_Shipments  Avg_Lead_Time  \
# 0           Lot's O' Nuts → Alabama               34           4.59
# 1           Lot's O' Nuts → Alberta               16           3.50
# 2           Lot's O' Nuts → Arizona              111           3.86
# 3          Lot's O' Nuts → Arkansas               31           4.19
# 4  Lot's O' Nuts → British Columbia               18           5.00
#
#    Lead_Time_Std  Min_Lead_Time  Max_Lead_Time
# 0           1.84              1              7
# 1           1.32              2              7
# 2           2.03              0              7
# 3           1.54              0              7
# 4           1.53              2              7

# %%
# Rank routes (lower lead time = better)
route_state["Efficiency_Rank"] = route_state["Avg_Lead_Time"].rank(method="dense")

# %%
route_state.sort_values("Efficiency_Rank").head()
# Out:
#                             Route_State  Total_Shipments  Avg_Lead_Time  \
# 129  The Other Factory → North Carolina                1            0.0
# 120        The Other Factory → Kentucky                2            1.0
# 131          The Other Factory → Oregon                2            1.5
# 54        Lot's O' Nuts → West Virginia                2            1.5
# 112         The Other Factory → Arizona                2            2.0
#
#      Lead_Time_Std  Min_Lead_Time  Max_Lead_Time  Efficiency_Rank
# 129            NaN              0              0              1.0
# 120           1.41              0              2              2.0
# 131           0.71              1              2              3.0
# 54            2.12              0              3              3.0
# 112           0.00              2              2              4.0

# %% [markdown]
# ## Top 10 Most Efficient Routes
# Routes with lowest average lead time.

# %%
top_10_routes = route_state.sort_values("Avg_Lead_Time").head(10)

top_10_routes
# Out:
#                             Route_State  Total_Shipments  Avg_Lead_Time  \
# 129  The Other Factory → North Carolina                1           0.00
# 120        The Other Factory → Kentucky                2           1.00
# 131          The Other Factory → Oregon                2           1.50
# 54        Lot's O' Nuts → West Virginia                2           1.50
# 112         The Other Factory → Arizona                2           2.00
# 125          The Other Factory → Nevada                1           2.00
# 126   The Other Factory → New Hampshire                2           2.00
# 108             Sugar Shack → Tennessee                1           2.00
# 80          Secret Factory → New Mexico                2           2.00
# 62            Secret Factory → Colorado                7           2.14
#
#      Lead_Time_Std  Min_Lead_Time  Max_Lead_Time  Efficiency_Rank
# 129            NaN              0              0              1.0
# ...

# %% [markdown]
# ## Bottom 10 Least Efficient Routes
# Routes with highest average lead time.

# %%
bottom_10_routes = route_state.sort_values("Avg_Lead_Time", ascending=False).head(10)

bottom_10_routes
# Out:
#                                    Route_State  Total_Shipments  \
# 133           The Other Factory → Rhode Island                1
# 124               The Other Factory → Missouri                1
# 127             The Other Factory → New Jersey                3
# 71                   Secret Factory → Maryland                3
# 75                Secret Factory → Mississippi                1
# 99                      Sugar Shack → Delaware                1
# 107                 Sugar Shack → Rhode Island                1
# 78              Secret Factory → New Hampshire                1
# 138             The Other Factory → Washington                4
# 35   Lot's O' Nuts → Newfoundland And Labrador                6
#
#      Avg_Lead_Time  Lead_Time_Std  Min_Lead_Time  Max_Lead_Time  \
# 133           7.00            NaN              7              7
# 124           7.00            NaN              7              7
# 127           6.33           1.15              5              7
# ...

# %% [markdown]
# ## Route Efficiency Score
#
# We normalize average lead time into a score where:
#
# - Higher score = better efficiency
# - Lower score = worse efficiency

# %%
# Normalize lead time (min-max scaling)
min_lt = route_state["Avg_Lead_Time"].min()
max_lt = route_state["Avg_Lead_Time"].max()

route_state["Efficiency_Score"] = (
    (max_lt - route_state["Avg_Lead_Time"]) / (max_lt - min_lt)
) * 100

route_state["Efficiency_Score"] = route_state["Efficiency_Score"].round(2)

# %%
route_state.sort_values("Efficiency_Score", ascending=False).head()
# Out:
#                             Route_State  Total_Shipments  Avg_Lead_Time  \
# 129  The Other Factory → North Carolina                1            0.0
# 120        The Other Factory → Kentucky                2            1.0
# 54        Lot's O' Nuts → West Virginia                2            1.5
# 131          The Other Factory → Oregon                2            1.5
# 125          The Other Factory → Nevada                1            2.0
#
#      Lead_Time_Std  Min_Lead_Time  Max_Lead_Time  Efficiency_Rank  \
# 129            NaN              0              0              1.0
# 120           1.41              0              2              2.0
# 54            2.12              0              3              3.0
# 131           0.71              1              2              3.0
# 125            NaN              2              2              4.0
#
#      Efficiency_Score
# 129            100.00
# 120             85.71
# 54              78.57
# 131             78.57
# ...

# %%
#Performance Segmentation
# Categorize routes
route_state["Performance_Category"] = pd.cut(
    route_state["Efficiency_Score"],
    bins=[0, 40, 70, 100],
    labels=["Poor", "Average", "High"]
)

route_state.head()
# Out:
#                         Route_State  Total_Shipments  Avg_Lead_Time  \
# 0           Lot's O' Nuts → Alabama               34           4.59
# 1           Lot's O' Nuts → Alberta               16           3.50
# 2           Lot's O' Nuts → Arizona              111           3.86
# 3          Lot's O' Nuts → Arkansas               31           4.19
# 4  Lot's O' Nuts → British Columbia               18           5.00
#
#    Lead_Time_Std  Min_Lead_Time  Max_Lead_Time  Efficiency_Rank  \
# 0           1.84              1              7             79.0
# 1           1.32              2              7             21.0
# 2           2.03              0              7             38.0
# 3           1.54              0              7             60.0
# 4           1.53              2              7             86.0
#
#    Efficiency_Score Performance_Category
# 0             34.43                 Poor
# 1             50.00              Average
# 2             44.86              Average
# ...

# %% [markdown]
# ## Ship Mode Performance Comparison

# %%
# Load featured dataset
ncd = pd.read_csv("/content/featured_nassau_data.csv")

# Compare lead time by ship mode
ship_mode_perf = ncd.groupby("Ship Mode").agg(
    Avg_Lead_Time=("Shipping Lead Time", "mean"),
    Total_Shipments=("Order ID", "count")
).reset_index()

ship_mode_perf["Avg_Lead_Time"] = ship_mode_perf["Avg_Lead_Time"].round(2)

ship_mode_perf
# Out:
#         Ship Mode  Avg_Lead_Time  Total_Shipments
# 0     First Class           2.02             1548
# 1        Same Day           0.50              547
# 2    Second Class           3.48             1979
# 3  Standard Class           5.00             6120

# %%
route_state.head()
# Out:
#                         Route_State  Total_Shipments  Avg_Lead_Time  \
# 0           Lot's O' Nuts → Alabama               34           4.59
# 1           Lot's O' Nuts → Alberta               16           3.50
# 2           Lot's O' Nuts → Arizona              111           3.86
# 3          Lot's O' Nuts → Arkansas               31           4.19
# 4  Lot's O' Nuts → British Columbia               18           5.00
#
#    Lead_Time_Std  Min_Lead_Time  Max_Lead_Time  Efficiency_Rank  \
# 0           1.84              1              7             79.0
# 1           1.32              2              7             21.0
# 2           2.03              0              7             38.0
# 3           1.54              0              7             60.0
# 4           1.53              2              7             86.0
#
#    Efficiency_Score Performance_Category
# 0             34.43                 Poor
# 1             50.00              Average
# 2             44.86              Average
# ...

# %%
route_state.to_csv("/content/route_efficiency_benchmark.csv", index=False)
top_10_routes.to_csv("/content/top_10_routes.csv", index=False)
bottom_10_routes.to_csv("/content/bottom_10_routes.csv", index=False)
ship_mode_perf.to_csv("/content/ship_mode_performance.csv", index=False)

print("Benchmarking datasets saved successfully.")
# Out:
# Benchmarking datasets saved successfully.
